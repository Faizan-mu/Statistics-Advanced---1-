# %% [markdown]
# Question 1: What is a random variable in probability theory?
#
# Answaer:- *Answer 1)** In probability theory, a random variable is a fundamental concept used to quantify the outcomes of a random phenomenon by assigning numerical values to them. It acts as a bridge between a real-world random process (like flipping a coin or measuring rainfall) and mathematical analysis. A random variable is not "random" in the usual sense—it is actually a function that maps each outcome of a random experiment in the sample space to a real number.
#
# **For example** - When tossing a coin, we might define a random variable
# 𝑋
# X such that
# 𝑋
# =
# 1
# X=1 if the result is heads and
# 𝑋
# =
# 0
# X=0 if it is tails.
#
#  **There are two main types of random variables:**
#
#  **Discrete Variables**- A discrete random variable can take on a finite or countably infinite set of distinct values, such as the number of goals in a football match or the number of students present in class.
#
# **Continuous random variable**- It can assume any value within a certain range or interval, often representing measurements like temperature, height, or time, which can be infinitely precise. Random variables are essential because they allow us to define and calculate probabilities, expectations (averages), variances (spread), and other statistical properties using probability distributions. Thus, they are a core tool in statistics, data analysis, and many applied fields that involve uncertainty and decision-making.

# %% [markdown]
# **Question 2) What are the types of random variables?**
#
# **Answer 2)** Random variables are mainly classified into two types based on the type of values they can take-
#
# **1. Discrete Random Variable**
#
# - A discrete random variable takes countable values.
#
# - These values can be finite or countably infinite (like 0, 1, 2, 3, ...).
#
# **Examples:**
#
# - Number of heads when tossing 3 coins.
#
# - Number of students present in class.
#
# - Number of cars passing a toll booth in one hour.
#
# **Key Features:**
#
# - Values are separated and distinct.
#
# - Probability can be assigned to each specific value using a probability mass function (PMF).
#
# **2. Continuous Random Variable**-
#
# A continuous random variable takes uncountably infinite values within an interval or range.
#
# These values are often measurable quantities.
#
# **Examples:**
#
# - Height or weight of a person.
#
# - Time taken to finish a race.
#
# - Temperature on a given day.
#
# **Key Features:**
#
# - Values form a continuous scale.
#
# - Probability is measured over an interval using a probability density function (PDF).
#
# - Probability of taking an exact value is zero, but probability over a range is positive (e.g., P(5 < X < 10)).

# %% [markdown]
# **Question 3) Explain the difference between discrete and continuous distributions.**
#
# **Answer 3)** In probability theory, discrete and continuous distributions describe how the values of random variables are distributed, but they differ based on the type of values the variable can take.
#
# **Discrete distribution** It can applies to a discrete random variable, which takes on specific, countable values. The probabilities of these values are represented using a probability mass function (PMF). Each outcome has a distinct, non-zero probability, and the total sum of all probabilities is equal to 1. Examples of discrete distributions include the Binomial distribution, which models the number of successes in a fixed number of trials, and the Poisson distribution, which models the number of events occurring in a fixed interval of time or space.
#
# **Continuous distribution** It can applies to a continuous random variable, which can take on any value within a range or interval. Instead of individual probabilities, it uses a probability density function (PDF) to describe the likelihood of outcomes. Since there are infinitely many possible values, the probability of the variable taking any exact value is zero; instead, we calculate the probability over an interval (e.g., P(2 < X < 5)). Common continuous distributions include the Normal distribution (bell-shaped curve used in statistics) and the Exponential distribution (used to model time until an event occurs).

# %% [markdown]
# **Question 4: What is a binomial distribution, and how is it used in probability?**
#
# **Answer 4)** A binomial distribution is a type of probability distribution that describes the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure. It is used when you want to know the probability of getting a specific number of successes in repeated experiments under the same conditions.
#
# **The binomial distribution is defined by two parameters:**
#
# n = number of trials
#
# p = probability of success in a single trial
#
#
#
# The probability of getting exactly k successes in n trials is given by the binomial formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# **Where:**
#
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) is the binomial coefficient (number of ways to choose k successes from n trials),
#
# 𝑝
# 𝑘
# p
# k
#   is the probability of getting k successes,
#
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# (1−p)
# n−k
#   is the probability of getting (n – k) failures.
#
#
#
#
# **Conditions for Using Binomial Distribution:**
#
# 1) The experiment has a fixed number of trials (n).
#
# 2) Each trial has only two outcomes: success or failure.
#
# 3) The probability of success (p) is the same in each trial.
#
# 4) Trials are independent of each other.

# %% [markdown]
# *Question 5) What is the standard normal distribution, and why is it important?**
#
# **Answer 5)**The standard normal distribution is a special type of normal distribution that has a mean (μ) of 0 and a standard deviation (σ) of 1. It is a bell-shaped, symmetric curve that shows how values of a normally distributed variable are spread around the mean. The horizontal axis represents standard scores (z-scores), which tell us how many standard deviations a value is from the mean.
#
# **The equation of the standard normal distribution is:**
#
# 𝑓
# (
# 𝑧
# )
# =
# 1
# 2
# 𝜋
# 𝑒
# −
# 𝑧
# 2
# /
# 2
# f(z)=
# 2π
# ​
#
# 1
# ​
#  e
# −z
# 2
#  /2
#
# **where**
# 𝑧
# **z is the z-score, calculated by:**
#
# 𝑧
# =
# 𝑋
# −
# 𝜇
# 𝜎
# z=
# σ
# X−μ
# ​
#
# **Why Is It Important?**
#
# **1) Universal Reference:** The standard normal distribution serves as a benchmark. Any normal distribution can be converted (standardized) into a standard normal distribution using z-scores, making different datasets comparable.
#
# **2) Simplifies Probability Calculations:** Probabilities for the standard normal distribution are available in z-tables (or calculated using software), allowing quick and easy calculation of the likelihood of an event occurring within a given range.
#
# **3) Used in Hypothesis Testing:** It plays a central role in statistical tests like the z-test, which is used to compare sample means to population means.
#
# **4) Central Limit Theorem:** This theorem states that, for large enough sample sizes, the sampling distribution of the sample mean will be approximately normal—even if the original data is not. This makes the standard normal distribution widely applicable.
#
# **5) Confidence Intervals:** It helps in constructing confidence intervals for estimating population parameters. For example, about 95% of values in a standard normal distribution fall within ±1.96 standard deviations from the mean.

# %% [markdown]
# **Question 6) What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# **Answer 6)**The Central Limit Theorem (CLT) is one of the most important concepts in statistics. It states that when independent random variables are added, their normalized sum tends toward a normal distribution (bell curve)—even if the original variables themselves are not normally distributed—provided the sample size is sufficiently large.
#
# More specifically, the CLT says that if you take multiple random samples of size
# 𝑛
# n from any population (with finite mean
# 𝜇
# μ and finite standard deviation
# 𝜎
# σ), then the sampling distribution of the sample mean (
# 𝑋
# ˉ
# X
# ˉ
#  ) will:
#
# - Become approximately normally distributed,
#
# - Have a mean equal to the population mean (
# 𝜇
# μ),
#
# - Have a standard deviation equal to
# 𝜎
# /
# 𝑛
# σ/
# n
# ​
#  , called the standard error.
#
# This approximation improves as the sample size increases, and typically, a sample size of 30 or more is considered sufficient.

# %% [markdown]
# **Question 7) What is the significance of confidence intervals in statistical analysis?**
#
# **Answer 7) A confidence interval (CI)** is a range of values, derived from sample data, that is used to estimate an unknown population parameter, such as the mean or proportion. It provides not just a single estimate (like a sample mean), but a range within which we are reasonably certain the true value lies. The confidence level (commonly 90%, 95%, or 99%) indicates how confident we are that this range contains the true parameter.
#
#
#
# **Significance of Confidence Intervals:**
#
# **1) Provides a Range, Not Just a Point**
#
# Instead of guessing one value (e.g., population mean = 70), a CI gives a range (e.g., 67 to 73), which is a more informative and realistic estimate.
#
# **2) Measures Uncertainty**
#
# Confidence intervals reflect the degree of uncertainty or variability in the estimate. A wider interval means more uncertainty; a narrower interval indicates more precision.
#
# **3) Supports Decision-Making**
#
# In research, business, and science, CIs help assess the reliability of sample results. For example, if a 95% CI for a drug's effect does not include zero, it may indicate the drug is effective.
#
# **4) Used in Hypothesis Testing**
#
# Confidence intervals can be used as an alternative to p-values in hypothesis testing. If the hypothesized value (e.g., mean = 50) falls outside the CI, we may reject the null hypothesis.
#
# **5) Applies Across Fields**
#
# Whether in medicine (estimating effectiveness of treatment), economics (estimating unemployment rates), or manufacturing (estimating defect rates), CIs provide a standard method for expressing statistical conclusions.

# %% [markdown]
# **Question 8) What is the concept of expected value in a probability distribution?**
#
# **Answer 8)**The expected value (also called the mean or mathematical expectation) of a probability distribution is the average value we would expect to obtain if an experiment were repeated many times. It represents the long-run average outcome of a random variable.
#
# Mathematically, the expected value is a weighted average of all possible values that a random variable can take, where each value is weighted by its probability.
#
#
# **For a Discrete Random Variable:**
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# [
# 𝑥
# 𝑖
# ⋅
# 𝑃
# (
# 𝑥
# 𝑖
# )
# ]
# E(X)=∑[x
# i
# ​
#  ⋅P(x
# i
# ​
#  )]
#
# **Where:**
#
# - 𝑥
# 𝑖
# x
# i
# ​
#   = possible values of the random variable
#
# - 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# ​
#  ) = probability of each value
#
# **For a Continuous Random Variable:**
#
# - 𝐸
# (
# 𝑋
# )
# =
# ∫
# −
# ∞
# ∞
# 𝑥
# ⋅
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫
# −∞
# ∞
# ​
#  x⋅f(x)dx
# Where:
#
# - 𝑓
# (
# 𝑥
# )
# f(x) = probability density function (PDF)

# %%
""" Question 9) Write a Python program to generate 1000 random numbers from a normal
distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
deviation using NumPy, and draw a histogram to visualize the distribution. """

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate 1000 random numbers from a normal distribution
data = np.random.normal(loc=50, scale=5, size=1000)

# Step 2: Compute the mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

print(f"Calculated Mean: {mean:.2f}")
print(f"Calculated Standard Deviation: {std_dev:.2f}")

# Step 3: Plot the histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean = {mean:.2f}')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculated Mean: 50.13
# Calculated Standard Deviation: 5.11

# %%
""" Question 10: You are working as a data analyst for a retail company. The company has
collected daily sales data for 2 years and wants you to identify the overall sales trend.
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
● Explain how you would apply the Central Limit Theorem to estimate the average sales
with a 95% confidence interval.
● Write the Python code to compute the mean sales and its confidence interval. """

import numpy as np
import scipy.stats as stats

# Sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]


mean_sales = np.mean(daily_sales)
std_dev_sales = np.std(daily_sales, ddof=1)
n = len(daily_sales)

standard_error = std_dev_sales / np.sqrt(n)


z_value = 1.96


margin_of_error = z_value * standard_error


lower_bound = mean_sales - margin_of_error
upper_bound = mean_sales + margin_of_error

# Output results
print(f"Sample Mean Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean Sales: 248.25
# 95% Confidence Interval: (240.68, 255.82)
